# %% [markdown]
# <a href="https://colab.research.google.com/github/AkbarBunyad/Training_Programs/blob/main/gi_group_ds/assignments/Small_Homework_8_(Scholarship).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Good luck!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/titanic.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171     7.25   NaN        S
# 1      0          PC 17599  712.833   C85        C
# 2      0  STON/O2. 3101282    7.925   NaN        S
# 3      0            113803     53.1  C123        S
# 4      0            373450    08.05   NaN        S

# %% [markdown]
# **1. Write a Pandas program to compare the elements of the two Pandas Series.**
#
# **Sample Series: [3, 4, 8, 2, 10], [1, 4, 6, 7, 14]**

# %%
series1 = pd.Series([3, 4, 8, 2, 10])
series2 = pd.Series([1, 4, 6, 7, 14])

com = series1 == series2

print(f"Comparison Result: \n{com}")
# Out:
# Comparison Result:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# **2. Write a Pandas program to convert a NumPy array to a Pandas series.**
#
# **  NumPy array:
# [10 20 30 40 50]
# Converted Pandas series:
#
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
#
# dtype: int64**

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
series = pd.Series(arr)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# **3.Read the data "Titanic" and print the first 5 and last 5 rows.**

# %%
df[:5]
df[:-5]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **4. Print the names of the columns.**

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# **5. Print the number of rows and columns of the data.**

# %%
print(f'rows: {df.shape[0]}, columns: {df.shape[1]}')
# Out:
# rows: 891, columns: 12

# %% [markdown]
# **6. Print general information about the data.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %% [markdown]
# **7. Print statistical information about the data.**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000

# %% [markdown]
# **8. Print the sum of all null values in the data by column.**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **9. Replace the null values in the "Age" column with the mode of the "Age" column.**

# %%
md = df['Age'].mode()[0]
df['Age'].fillna(md, inplace = True)
#df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **10. Print statistical data for columns whose data type is object.**

# %%
lst = []
for i in df.columns:
  if df[i].dtype == 'object':
    lst+=[i]
df[lst].describe()
# Out:
#                            Name   Sex  Ticket   Fare    Cabin Embarked
# count                       891   891     891    891      204      889
# unique                      891     2     681    248      147        3
# top     Braund, Mr. Owen Harris  male  347082  08.05  B96 B98        S
# freq                          1   577       7     43        4      644
