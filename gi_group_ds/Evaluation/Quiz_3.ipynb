# %% [markdown]
# <a href="https://colab.research.google.com/github/AkbarBunyad/Training_Programs/blob/main/gi_group_ds/Evaluation/Quiz_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
path ='/content/drive/MyDrive/Colab Notebooks/gi_group/Datasets/covid_19_data.csv'
df = pd.read_csv()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %% [markdown]
# #1

# %%
df = df.sort_values(by = 'ObservationDate', ascending = False)

# %%
df.groupby('ObservationDate')['SNo'].count().sort_values(ascending = False).head(1)
# Out:
# ObservationDate
# 03/18/2020    284
# Name: SNo, dtype: int64

# %% [markdown]
# #2

# %%
df[df['ObservationDate'] == '03/18/2020'].groupby('Province/State')['Deaths'].sum().sort_values(ascending = False)
# Out:
# Province/State
# Hubei             3122.0
# France             148.0
# United Kingdom      71.0
# Netherlands         58.0
# Washington          55.0
#                    ...
# Mayotte              0.0
# Massachusetts        0.0
# Maryland             0.0
# Manitoba             0.0
# Minnesota            0.0
# Name: Deaths, Length: 127, dtype: float64

# %% [markdown]
# #3

# %%
df[df['ObservationDate'] == '03/18/2020'].groupby('Province/State')['Deaths'].sum().sort_values(ascending = False)
# Out:
# Province/State
# Hubei             3122.0
# France             148.0
# United Kingdom      71.0
# Netherlands         58.0
# Washington          55.0
#                    ...
# Mayotte              0.0
# Massachusetts        0.0
# Maryland             0.0
# Manitoba             0.0
# Minnesota            0.0
# Name: Deaths, Length: 127, dtype: float64

# %%
df['Mortality Rate'] = df['Deaths'] / df['Confirmed']
df.head()
# Out:
#        SNo ObservationDate Province/State        Country/Region  \
# 6721  6722      03/18/2020            NaN            The Gambia
# 6534  6535      03/18/2020     Queensland             Australia
# 6528  6529      03/18/2020            NaN  United Arab Emirates
# 6529  6530      03/18/2020            NaN               Ecuador
# 6530  6531      03/18/2020            NaN              Slovakia
#
#               Last Update  Confirmed  Deaths  Recovered  Mortality Rate
# 6721  2020-03-18T14:13:56        0.0     0.0        0.0             NaN
# 6534  2020-03-18T11:53:04       94.0     0.0        8.0        0.000000
# 6528  2020-03-18T02:33:06      113.0     0.0       26.0        0.000000
# 6529  2020-03-18T03:13:19      111.0     2.0        0.0        0.018018
# 6530  2020-03-18T14:13:14      105.0     1.0        0.0        0.009524

# %%
lst = df.sort_values(by = 'Confirmed', ascending = False)['Country/Region'].unique()[:5]

# %%
lst
# Out:
# array(['Mainland China', 'Italy', 'Iran', 'Spain', 'Germany'],
#       dtype=object)

# %%
df[df['Country/Region'].isin(lst)].sort_values(by = 'ObservationDate', ascending = True).dropna()
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 0        1      01/22/2020          Anhui  Mainland China
# 17      18      01/22/2020        Jiangxi  Mainland China
# 16      17      01/22/2020        Jiangsu  Mainland China
# 14      15      01/22/2020          Hunan  Mainland China
# 13      14      01/22/2020          Hubei  Mainland China
# ...    ...             ...            ...             ...
# 6470  6471      03/18/2020        Beijing  Mainland China
# 6438  6439      03/18/2020          Hubei  Mainland China
# 6455  6456      03/18/2020       Zhejiang  Mainland China
# 6468  6469      03/18/2020        Sichuan  Mainland China
# 6536  6537      03/18/2020          Jilin  Mainland China
#
#               Last Update  Confirmed  Deaths  Recovered  Mortality Rate
# 0         1/22/2020 17:00        1.0     0.0        0.0        0.000000
# 17        1/22/2020 17:00        2.0     0.0        0.0        0.000000
# ...

# %% [markdown]
# #4

# %%
df['Recovery Rate'] = df['Recovered'] / df['Confirmed']
df = df[df['Confirmed'] > 1000]
df = df[df['ObservationDate'] == df['ObservationDate'].max()].dropna()
df.sort_values(by = 'Recovery Rate', ascending = False).head(3)
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 6457  6458      03/18/2020          Hunan  Mainland China
# 6455  6456      03/18/2020       Zhejiang  Mainland China
# 6454  6455      03/18/2020          Henan  Mainland China
#
#               Last Update  Confirmed  Deaths  Recovered  Mortality Rate  \
# 6457  2020-03-14T08:33:03     1018.0     4.0     1014.0        0.003929
# 6455  2020-03-17T02:13:21     1232.0     1.0     1216.0        0.000812
# 6454  2020-03-14T09:53:08     1273.0    22.0     1250.0        0.017282
#
#       Recovery Rate
# 6457       0.996071
# 6455       0.987013
# 6454       0.981932

# %% [markdown]
# #5

# %%
df[df['Last Update'] == df['Last Update'].min()]['Country/Region'].unique()
# Out:
# array(['Mainland China'], dtype=object)

# %% [markdown]
# #6

# %%
df[df['ObservationDate'] == df['ObservationDate'].min()]['Recovered'].sum()
# Out:
# 61800.0
